# %%
import pandas as pd

df = pd.read_csv("Sorting_Results.csv", index_col=0)

# %%
print(df)
# Out:
#                   Bubble 10^1  Insertion 10^1  Quick 10^1  Bubble 10^2
# Random               0.521434        0.174463    1.482030     0.000078  \
# Fully Sorted         0.000025        0.000012    0.000505     0.000013
# Reverse Sorted       0.000025        0.000012    0.000518     0.000044
# Partially Sorted     0.000025        0.000012    0.000510     0.000049
#
#                   Insertion 10^2  Quick 10^2  Bubble 10^3  Insertion 10^3
# Random                  0.000023    0.003523     0.004572        0.000820  \
# Fully Sorted            0.000011    0.003568     0.000021        0.000018
# Reverse Sorted          0.000034    0.003587     0.002555        0.001556
# Partially Sorted        0.000013    0.003508     0.003051        0.000136
#
#                   Quick 10^3  Bubble 10^4  Insertion 10^4  Quick 10^4
# Random              0.035947     0.544744        0.067278    0.345749  \
# Fully Sorted        0.034573     0.000102        0.000074    0.345749
# ...

# %%
df.plot(y=['Bubble 10^1', 'Insertion 10^1', 'Quick 10^1'], kind='line')
# Out:
# <Axes: >

# %%
df.plot(y=['Bubble 10^2', 'Insertion 10^2', 'Quick 10^2'], kind='line')
# Out:
# <Axes: >

# %%
df.plot(y=['Bubble 10^3', 'Insertion 10^3', 'Quick 10^3'], kind='line')
# Out:
# <Axes: >

# %%
df.plot(y=['Bubble 10^4', 'Insertion 10^4', 'Quick 10^4'], kind='line')
# Out:
# <Axes: >

# %%
df.plot(y=['Bubble 10^5', 'Insertion 10^5', 'Quick 10^5'], kind='line')
# Out:
# <Axes: >
